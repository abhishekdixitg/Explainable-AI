# %% [markdown]
# # BIRD SPECIES CLASSIFICATION with DEEP LEARNING

# %% [markdown]
# <p style="text-align:center;"><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-zuTVRKn8MQ4ZiHcK-WU1QoCzoYw_V7Yh9g&usqp=CAU" alt="Girl in a jacket" width="500" height="600" class="center"></p>

# %% [markdown]
# **Project Overview**
#
# It is a project that uses transfer learning to predict 450 classes belonging to bird species. Data set of 400 bird species.58388 training images, 2000 test images(5 images per species) and 2000 validation images(5 images per species. This is a very high quality dataset where there is only one bird in each image and the bird typically takes up at least 50% of the pixels in the image. As a result even a moderatly complex model will achieve training and test accuracies in the mid 90% range.
#
# To become one with data is significant in such projects. Therefore, visualization techniques are usually applied in the project. A pre-trained model of Keras (InceptionV3) is  used in the project. After reachin nearly %89 accuracy, fine-tuning is applied and the accuracy is improved to **%94**.
#
# Steps followed during the development of the project:
#
# * 1. Become One with Data
# * 2. Data Preprocessing
# * 3. Create a and fit the Model (Using InceptionV3 pre-trained model)
# * 4. Freeze top layers of Base Model
# * 5. Fine-tuning and Refitting

# %%
## 1. Become one with the data

# %%
import os 

#walk through the directory and list the numbers of files
for dirpath, dirnames, filenames in os.walk("/kaggle/input/100-bird-species"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")
# Out:
# There are 4 directories and 2 images in /kaggle/input/100-bird-species
# There are 0 directories and 6 images in /kaggle/input/100-bird-species/images to predict
# There are 510 directories and 0 images in /kaggle/input/100-bird-species/valid
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DALMATIAN PELICAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WATTLED CURASSOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN WIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CARMINE BEE-EATER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GAMBELS QUAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/UMBRELLA BIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN KESTREL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN GOLDFINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE GROSBEAK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PALM NUT VULTURE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DUSKY LORY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AUCKLAND SHAQ
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK THROATED WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/YELLOW CACIQUE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STRIPPED SWALLOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VERMILION FLYCATHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPE MAY WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED TAILED HAWK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GURNEYS PITTA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIAN ROLLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SNOW GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREEN WINGED DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AZURE TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREEN MAGPIE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BANDED BROADBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN PYGMY GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIGO FLYCATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREY PLOVER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TOUCHAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HYACINTH MACAW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HARLEQUIN DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ABYSSINIAN GROUND HORNBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CALIFORNIA QUAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BALD IBIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WOOD THRUSH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUBY THROATED HUMMINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIGO BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ALBERTS TOWHEE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SORA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HOODED MERGANSER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROSEATE SPOONBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPE ROCK THRUSH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE COAU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CALIFORNIA CONDOR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BORNEAN PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BARN SWALLOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TAIWAN MAGPIE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SPLENDID WREN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED BILLED TROPICBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK THROATED BUSHTIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHINESE POND HERON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN EMERALD CUCKOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON LOON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON POORWILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROSE BREASTED COCKATOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FIORDLAND PENGUIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SUPERB STARLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CUBAN TODY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TASMANIAN HEN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK SWAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WATTLED LAPWING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED NAPED TROGON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SUNBITTERN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN PIPIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN TOWEE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GYRFALCON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK SKIMMER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED BEARDED BEE EATER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ALBATROSS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE EARED HUMMINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EGYPTIAN GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MASKED LAPWING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LAUGHING GULL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN ROBIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MALABAR HORNBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OCELLATED TURKEY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PEREGRINE FALCON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SQUACCO HERON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHINESE BAMBOO PARTRIDGE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IBISBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROSY FACED LOVEBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREATOR SAGE GROUSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MILITARY MACAW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHATTERING LORY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VISAYAN HORNBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AZARAS SPINETAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUFOUS KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LOONEY BIRDS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JABIRU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE BREASTED WATERHEN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT KISKADEE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GRAY KINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GUINEAFOWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN MOCKINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE CRESTED HORNBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MALLARD DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GILA WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BROWN HEADED COWBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MASKED BOOBY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN BITTERN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CALIFORNIA GULL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CASPIAN TERN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EMERALD TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BANDED PITA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AZURE JAY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BARRED PUFFBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ELEGANT TROGON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SNOWY EGRET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EUROPEAN TURTLE DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED SHRIKETIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SATYR TRAGOPAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GANG GANG COCKATOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMETHYST WOODSTAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED HEADED WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MIKADO  PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FIRE TAILLED MYZORNIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BUFFLEHEAD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT TINAMOU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SWINHOES PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PARADISE TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OVENBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GRANDALA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN BLUEBONNET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MOURNING DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK FACED SPOONBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BROWN NOODY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WALL CREAPER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ORIENTAL BAY OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DOWNY WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EMPEROR PENGUIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE TAILED TROPIC
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FIERY MINIVET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OSPREY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HOUSE FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SNOWY PLOVER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN COOT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN PIPIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PUFFIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ARARIPE MANAKIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUDY KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK-CAPPED CHICKADEE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ABBOTTS BABBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREEN BROADBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KAKAPO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RAZORBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED LEGGED HONEYCREEPER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK BAZA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANTILLEAN EUPHONIA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BEARDED REEDLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BELTED KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KILLDEAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PLUSH CRESTED JAY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HELMET VANGA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BAR-TAILED GODWIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED OROPENDOLA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STRIPPED MANAKIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPE LONGCLAW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CREAM COLORED WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN BEARDLESS TYRANNULET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED SHOULDERED HAWK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED TAILED THRUSH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STEAMER DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED BELLIED PITTA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GRAY CATBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GUINEA TURACO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUDDY SHELDUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED WISKERED BULBUL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PATAGONIAN SIERRA FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PHILIPPINE EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED FODY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANHINGA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VEERY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SPOTTED WHISTLING DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BRANDT CORMARANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SPOON BILED SANDPIPER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VULTURINE GUINEAFOWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ENGGANO MYNA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT XENOPS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SAYS PHOEBE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BIRD OF PARADISE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LILAC ROLLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BAIKAL TEAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CINNAMON ATTILA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BANANAQUIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JOCOTOCO ANTPITTA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHUKAR PARTRIDGE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRIMSON CHAT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN GOLDEN WEAVER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CACTUS WREN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BALD EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPE GLOSSY STARLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BURCHELLS COURSER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IVORY BILLED ARACARI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NICOBAR PIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KIWI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN FIREFINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED NUTHATCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLD WING WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE BROWED CRAKE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COCKATOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE THROATED TOUCANET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAATINGA CACHOLOTE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EMU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FAIRY TERN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HARPY EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANDEAN SISKIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DOUBLE EYED FIG PARROT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE MALKOHA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT ARGUS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CUBAN TROGON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VIOLET TURACO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLONDE CRESTED WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ASHY THRUSHBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE HERON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EURASIAN MAGPIE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED WINGED BLACKBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ZEBRA DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BORNEAN BRISTLEHEAD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FAN TAILED WIDOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WRENTIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COLLARED CRESCENTCHEST
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CANVASBACK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FOREST WAGTAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHESTNET BELLIED EUPHONIA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IBERIAN MAGPIE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SCARLET CROWNED FRUIT DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ORANGE BRESTED BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SCARLET TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ASIAN DOLLARD BIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANDEAN LAPWING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MAGPIE GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KING EIDER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK THROATED HUET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE THROATED BEE EATER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TROPICAL KINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK FRANCOLIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ASHY STORM PETREL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COLLARED ARACARI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED AUKLET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GLOSSY IBIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN CARDINAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KAGU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SURF SCOTER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PURPLE FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANDEAN GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HORNED SUNGEM
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MYNA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON HOUSE MARTIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EURASIAN GOLDEN ORIOLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN SHOVELER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AVADAVAT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PARAKETT  AKULET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANTBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PHAINOPEPLA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/POMARINE JAEGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE GRAY GNATCATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CLARKS GREBE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/APOSTLEBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COPPERY TAILED COUCAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ALEXANDRINE PARAKEET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MCKAYS BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CEDAR WAXWING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KING VULTURE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SAND MARTIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SMITHS LONGSPUR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ALPINE CHOUGH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PYGMY KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOULDIAN FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED WOOD PARTRIDGE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CROW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED KNOT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BROWN CREPPER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TAWNY FROGMOUTH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NOISY FRIARBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CERULEAN WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAMPO FLICKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE CHEEKED TURACO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BARN OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STRIPED OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TAILORBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VIOLET BACKED STARLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IVORY GULL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OSTRICH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROUGH LEG BUZZARD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RAINBOW LORIKEET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BAND TAILED GUAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/APAPANE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HIMALAYAN BLUETAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PARUS MAJOR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LONG-EARED OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED FIREBACK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN YELLOW ROBIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MARABOU STORK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EURASIAN BULLFINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK TAIL CRAKE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN BOWER BIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INCA TERN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PAINTED BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN BLUEBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PALILA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HOOPOES
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OKINAWA RAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AUSTRALASIAN FIGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHIPPING SPARROW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TRICOLORED BLACKBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN FLAMINGO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WILLOW PTARMIGAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANNAS HUMMINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CINNAMON TEAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SCARLET FACED LIOCICHLA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WOODLAND KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VENEZUELIAN TROUPIAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HEPATIC TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MALEO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IWI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHITE NECKED RAVEN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PINK ROBIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BOBOLINK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MANDRIN DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED BROWED FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PYRRHULOXIA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN PARULA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COPPERSMITH BARBET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN AVOCET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EVENING GROSBEAK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED HEADED DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TREE SWALLOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON GRACKLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SCARLET MACAW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HORNED GUAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK VENTED SHEARWATER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPUCHINBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CROWNED PIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MANGROVE CUCKOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRAB PLOVER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CINNAMON FLYCATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WILD TURKEY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DUSKY ROBIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VIOLET GREEN SWALLOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AUSTRAL CANASTERO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BUSH TURKEY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN PARAKEET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LESSER ADJUTANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREEN JAY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ALTAMIRA YELLOWTHROAT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FRILL BACK PIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BEARDED BELLBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FLAME BOWERBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PUNA TEAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LIMPKIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUFUOS MOTMOT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN JACANA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ECUADORIAN HILLSTAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROADRUNNER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE GROUSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CAPPED HERON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TEAL DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DARK EYED JUNCO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LOGGERHEAD SHRIKE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CLARKS NUTCRACKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GILDED FLICKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHUCAO TAPACULO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BALI STARLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREY CUCKOOSHRIKE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VERDIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT GRAY OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROCK DOVE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BREWERS BLACKBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LUCIFER HUMMINGBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLOOD PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ORNATE HAWK EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN PIED HORNBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CHARA DE COLLAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TOWNSENDS WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/D-ARNAUDS BARBET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MERLIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/OYSTER CATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VARIED THRUSH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUFOUS TREPE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SRI LANKA BLUE MAGPIE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LARK BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DOUBLE BARRED FINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FAIRY BLUEBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRIMSON SUNBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HARLEQUIN QUAIL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HOUSE SPARROW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED CARACARA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN GANNET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SCARLET IBIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MALACHITE KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIAN PITTA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN MEADOWLARK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/REGENT BOWERBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WILSONS BIRD OF PARADISE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON IORA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK NECKED STILT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SHORT BILLED DOWITCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK-THROATED SPARROW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DARJEELING WOODPECKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN FLICKER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BANDED STILT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PURPLE GALLINULE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CANARY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TAKAHE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JANDAYA PARAKEET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FLAME TANAGER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CURL CRESTED ARACURI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FASCIATED WREN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREATER PEWEE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED FACED CORMORANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT JACAMAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROSE BREASTED GROSBEAK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ROYAL FLYCATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN FULMAR
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EARED PITA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BULWERS PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HORNED LARK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HAWFINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COCK OF THE  ROCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TIT MOUSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GRAY PARTRIDGE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AZURE BREASTED PITTA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ANIANIAU
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WOOD DUCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GROVED BILLED ANI
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RED FACED WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HIMALAYAN MONAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DEMOISELLE CRANE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED COUA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/QUETZAL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN GOSHAWK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN CHLOROPHONIA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RUBY CROWNED KINGLET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PURPLE SWAMPHEN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON FIRECREST
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TURQUOISE MOTMOT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CASSOWARY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIAN BUSTARD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/KOOKABURRA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SANDHILL CRANE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/RING-NECKED PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MASKED BOBWHITE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN ROSELLA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREY HEADED FISH EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PURPLE MARTIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/VICTORIA CROWNED PIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SHOEBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SNOWY OWL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN CROWNED CRANE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREAT POTOO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STORK BILLED KINGFISHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK HEADED CAIQUE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AFRICAN OYSTER CATCHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ASIAN CRESTED IBIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EASTERN WIP POOR WILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LITTLE AUK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK-NECKED GREBE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ABBOTTS BOOBY
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BALTIMORE ORIOLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/COMMON STARLING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HAMERKOP
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INDIAN VULTURE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JAPANESE ROBIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACKBURNIAM WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/WHIMBREL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/YELLOW HEADED BLACKBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SPOTTED CATBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK COCKATO
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SPANGLED COTINGA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FAIRY PENGUIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/MALAGASY WHITE EYE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HAWAIIAN GOOSE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/PEACOCK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BEARDED BARBET
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TURKEY VULTURE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JACK SNIPE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ASIAN GREEN BEE EATER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK VULTURE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BROWN THRASHER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLUE DACNIS
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DAURIAN REDSTART
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/STRIATED CARACARA
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GREATER PRAIRIE CHICKEN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN CHEEKED WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/DOUBLE BRESTED CORMARANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JAVA SPARROW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BAY-BREASTED WARBLER
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AZURE TIT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/HOATZIN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GO AWAY BIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/ELLIOTS  PHEASANT
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/JACOBIN PIGEON
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRESTED SERPENT EAGLE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/IMPERIAL SHAQ
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BARROWS GOLDENEYE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/FRIGATE
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/TRUMPTER SWAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/INLAND DOTTEREL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/SAMATRAN THRUSH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BLACK AND YELLOW BROADBILL
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/BORNEAN LEAFBIRD
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/LAZULI BUNTING
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/EUROPEAN GOLDFINCH
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/AMERICAN REDSTART
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/CRANE HAWK
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/NORTHERN RED BISHOP
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/valid/GOLDEN EAGLE
# There are 510 directories and 0 images in /kaggle/input/100-bird-species/test
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/test/DALMATIAN PELICAN
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/test/WATTLED CURASSOW
# There are 0 directories and 5 images in /kaggle/input/100-bird-species/test/AMERICAN WIGEON
# ...
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/GOLDEN PARAKEET
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/LESSER ADJUTANT
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/GREEN JAY
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/ALTAMIRA YELLOWTHROAT
# There are 0 directories and 209 images in /kaggle/input/100-bird-species/train/FRILL BACK PIGEON
# There are 0 directories and 142 images in /kaggle/input/100-bird-species/train/BEARDED BELLBIRD
# There are 0 directories and 162 images in /kaggle/input/100-bird-species/train/FLAME BOWERBIRD
# There are 0 directories and 185 images in /kaggle/input/100-bird-species/train/PUNA TEAL
# There are 0 directories and 200 images in /kaggle/input/100-bird-species/train/LIMPKIN
# There are 0 directories and 189 images in /kaggle/input/100-bird-species/train/RUFUOS MOTMOT
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/CRESTED KINGFISHER
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/NORTHERN JACANA
# There are 0 directories and 139 images in /kaggle/input/100-bird-species/train/ECUADORIAN HILLSTAR
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/ROADRUNNER
# There are 0 directories and 185 images in /kaggle/input/100-bird-species/train/BLUE GROUSE
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/CAPPED HERON
# There are 0 directories and 159 images in /kaggle/input/100-bird-species/train/TEAL DUCK
# There are 0 directories and 203 images in /kaggle/input/100-bird-species/train/DARK EYED JUNCO
# There are 0 directories and 190 images in /kaggle/input/100-bird-species/train/LOGGERHEAD SHRIKE
# There are 0 directories and 161 images in /kaggle/input/100-bird-species/train/CLARKS NUTCRACKER
# There are 0 directories and 138 images in /kaggle/input/100-bird-species/train/GILDED FLICKER
# There are 0 directories and 141 images in /kaggle/input/100-bird-species/train/CHUCAO TAPACULO
# There are 0 directories and 132 images in /kaggle/input/100-bird-species/train/BALI STARLING
# There are 0 directories and 159 images in /kaggle/input/100-bird-species/train/GREY CUCKOOSHRIKE
# There are 0 directories and 182 images in /kaggle/input/100-bird-species/train/VERDIN
# There are 0 directories and 144 images in /kaggle/input/100-bird-species/train/GREAT GRAY OWL
# There are 0 directories and 132 images in /kaggle/input/100-bird-species/train/ROCK DOVE
# There are 0 directories and 183 images in /kaggle/input/100-bird-species/train/BREWERS BLACKBIRD
# There are 0 directories and 168 images in /kaggle/input/100-bird-species/train/LUCIFER HUMMINGBIRD
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/BLOOD PHEASANT
# There are 0 directories and 208 images in /kaggle/input/100-bird-species/train/ORNATE HAWK EAGLE
# There are 0 directories and 187 images in /kaggle/input/100-bird-species/train/AFRICAN PIED HORNBILL
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/CHARA DE COLLAR
# There are 0 directories and 165 images in /kaggle/input/100-bird-species/train/TOWNSENDS WARBLER
# There are 0 directories and 233 images in /kaggle/input/100-bird-species/train/D-ARNAUDS BARBET
# There are 0 directories and 209 images in /kaggle/input/100-bird-species/train/MERLIN
# There are 0 directories and 207 images in /kaggle/input/100-bird-species/train/OYSTER CATCHER
# There are 0 directories and 193 images in /kaggle/input/100-bird-species/train/VARIED THRUSH
# There are 0 directories and 274 images in /kaggle/input/100-bird-species/train/RUFOUS TREPE
# There are 0 directories and 161 images in /kaggle/input/100-bird-species/train/SRI LANKA BLUE MAGPIE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/LARK BUNTING
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/DOUBLE BARRED FINCH
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/FAIRY BLUEBIRD
# There are 0 directories and 198 images in /kaggle/input/100-bird-species/train/CRIMSON SUNBIRD
# There are 0 directories and 134 images in /kaggle/input/100-bird-species/train/HARLEQUIN QUAIL
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/HOUSE SPARROW
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/CRESTED CARACARA
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/NORTHERN GANNET
# There are 0 directories and 138 images in /kaggle/input/100-bird-species/train/SCARLET IBIS
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/MALACHITE KINGFISHER
# There are 0 directories and 186 images in /kaggle/input/100-bird-species/train/INDIAN PITTA
# There are 0 directories and 190 images in /kaggle/input/100-bird-species/train/EASTERN MEADOWLARK
# There are 0 directories and 164 images in /kaggle/input/100-bird-species/train/REGENT BOWERBIRD
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/WILSONS BIRD OF PARADISE
# There are 0 directories and 133 images in /kaggle/input/100-bird-species/train/COMMON IORA
# There are 0 directories and 173 images in /kaggle/input/100-bird-species/train/BLACK NECKED STILT
# There are 0 directories and 164 images in /kaggle/input/100-bird-species/train/SHORT BILLED DOWITCHER
# There are 0 directories and 168 images in /kaggle/input/100-bird-species/train/BLACK-THROATED SPARROW
# There are 0 directories and 136 images in /kaggle/input/100-bird-species/train/DARJEELING WOODPECKER
# There are 0 directories and 139 images in /kaggle/input/100-bird-species/train/NORTHERN FLICKER
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/BANDED STILT
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/PURPLE GALLINULE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/CANARY
# There are 0 directories and 162 images in /kaggle/input/100-bird-species/train/TAKAHE
# There are 0 directories and 162 images in /kaggle/input/100-bird-species/train/JANDAYA PARAKEET
# There are 0 directories and 177 images in /kaggle/input/100-bird-species/train/FLAME TANAGER
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/CURL CRESTED ARACURI
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/FASCIATED WREN
# There are 0 directories and 157 images in /kaggle/input/100-bird-species/train/GREATER PEWEE
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/RED FACED CORMORANT
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/GREAT JACAMAR
# There are 0 directories and 174 images in /kaggle/input/100-bird-species/train/ROSE BREASTED GROSBEAK
# There are 0 directories and 142 images in /kaggle/input/100-bird-species/train/ROYAL FLYCATCHER
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/NORTHERN FULMAR
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/EARED PITA
# There are 0 directories and 159 images in /kaggle/input/100-bird-species/train/BULWERS PHEASANT
# There are 0 directories and 173 images in /kaggle/input/100-bird-species/train/HORNED LARK
# There are 0 directories and 167 images in /kaggle/input/100-bird-species/train/HAWFINCH
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/COCK OF THE  ROCK
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/TIT MOUSE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/GRAY PARTRIDGE
# There are 0 directories and 141 images in /kaggle/input/100-bird-species/train/AZURE BREASTED PITTA
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/ANIANIAU
# There are 0 directories and 214 images in /kaggle/input/100-bird-species/train/WOOD DUCK
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/GROVED BILLED ANI
# There are 0 directories and 167 images in /kaggle/input/100-bird-species/train/RED FACED WARBLER
# There are 0 directories and 151 images in /kaggle/input/100-bird-species/train/HIMALAYAN MONAL
# There are 0 directories and 139 images in /kaggle/input/100-bird-species/train/DEMOISELLE CRANE
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/CRESTED COUA
# There are 0 directories and 152 images in /kaggle/input/100-bird-species/train/QUETZAL
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/NORTHERN GOSHAWK
# There are 0 directories and 135 images in /kaggle/input/100-bird-species/train/GOLDEN CHLOROPHONIA
# There are 0 directories and 186 images in /kaggle/input/100-bird-species/train/RUBY CROWNED KINGLET
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/PURPLE SWAMPHEN
# There are 0 directories and 139 images in /kaggle/input/100-bird-species/train/COMMON FIRECREST
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/TURQUOISE MOTMOT
# There are 0 directories and 164 images in /kaggle/input/100-bird-species/train/CASSOWARY
# There are 0 directories and 131 images in /kaggle/input/100-bird-species/train/INDIAN BUSTARD
# There are 0 directories and 143 images in /kaggle/input/100-bird-species/train/KOOKABURRA
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/SANDHILL CRANE
# There are 0 directories and 152 images in /kaggle/input/100-bird-species/train/RING-NECKED PHEASANT
# There are 0 directories and 183 images in /kaggle/input/100-bird-species/train/MASKED BOBWHITE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/EASTERN ROSELLA
# There are 0 directories and 143 images in /kaggle/input/100-bird-species/train/GREY HEADED FISH EAGLE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/PURPLE MARTIN
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/VICTORIA CROWNED PIGEON
# There are 0 directories and 175 images in /kaggle/input/100-bird-species/train/SHOEBILL
# There are 0 directories and 161 images in /kaggle/input/100-bird-species/train/SNOWY OWL
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/AFRICAN CROWNED CRANE
# There are 0 directories and 138 images in /kaggle/input/100-bird-species/train/GREAT POTOO
# There are 0 directories and 135 images in /kaggle/input/100-bird-species/train/STORK BILLED KINGFISHER
# There are 0 directories and 183 images in /kaggle/input/100-bird-species/train/BLACK HEADED CAIQUE
# There are 0 directories and 161 images in /kaggle/input/100-bird-species/train/GOLDEN PHEASANT
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/AFRICAN OYSTER CATCHER
# There are 0 directories and 157 images in /kaggle/input/100-bird-species/train/ASIAN CRESTED IBIS
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/EASTERN WIP POOR WILL
# There are 0 directories and 175 images in /kaggle/input/100-bird-species/train/LITTLE AUK
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/BLACK-NECKED GREBE
# There are 0 directories and 180 images in /kaggle/input/100-bird-species/train/ABBOTTS BOOBY
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/BALTIMORE ORIOLE
# There are 0 directories and 141 images in /kaggle/input/100-bird-species/train/COMMON STARLING
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/HAMERKOP
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/INDIAN VULTURE
# There are 0 directories and 158 images in /kaggle/input/100-bird-species/train/JAPANESE ROBIN
# There are 0 directories and 134 images in /kaggle/input/100-bird-species/train/BLACKBURNIAM WARBLER
# There are 0 directories and 138 images in /kaggle/input/100-bird-species/train/WHIMBREL
# There are 0 directories and 159 images in /kaggle/input/100-bird-species/train/YELLOW HEADED BLACKBIRD
# There are 0 directories and 150 images in /kaggle/input/100-bird-species/train/SPOTTED CATBIRD
# There are 0 directories and 133 images in /kaggle/input/100-bird-species/train/BLACK COCKATO
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/SPANGLED COTINGA
# There are 0 directories and 154 images in /kaggle/input/100-bird-species/train/FAIRY PENGUIN
# There are 0 directories and 143 images in /kaggle/input/100-bird-species/train/MALAGASY WHITE EYE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/HAWAIIAN GOOSE
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/PEACOCK
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/BEARDED BARBET
# There are 0 directories and 164 images in /kaggle/input/100-bird-species/train/TURKEY VULTURE
# There are 0 directories and 159 images in /kaggle/input/100-bird-species/train/JACK SNIPE
# There are 0 directories and 220 images in /kaggle/input/100-bird-species/train/ASIAN GREEN BEE EATER
# There are 0 directories and 156 images in /kaggle/input/100-bird-species/train/BLACK VULTURE
# There are 0 directories and 165 images in /kaggle/input/100-bird-species/train/BROWN THRASHER
# There are 0 directories and 173 images in /kaggle/input/100-bird-species/train/BLUE DACNIS
# There are 0 directories and 146 images in /kaggle/input/100-bird-species/train/DAURIAN REDSTART
# There are 0 directories and 196 images in /kaggle/input/100-bird-species/train/STRIATED CARACARA
# There are 0 directories and 203 images in /kaggle/input/100-bird-species/train/GREATER PRAIRIE CHICKEN
# There are 0 directories and 176 images in /kaggle/input/100-bird-species/train/GOLDEN CHEEKED WARBLER
# There are 0 directories and 186 images in /kaggle/input/100-bird-species/train/DOUBLE BRESTED CORMARANT
# There are 0 directories and 164 images in /kaggle/input/100-bird-species/train/JAVA SPARROW
# There are 0 directories and 143 images in /kaggle/input/100-bird-species/train/BAY-BREASTED WARBLER
# There are 0 directories and 165 images in /kaggle/input/100-bird-species/train/AZURE TIT
# There are 0 directories and 155 images in /kaggle/input/100-bird-species/train/HOATZIN
# There are 0 directories and 131 images in /kaggle/input/100-bird-species/train/GO AWAY BIRD
# There are 0 directories and 163 images in /kaggle/input/100-bird-species/train/ELLIOTS  PHEASANT
# There are 0 directories and 204 images in /kaggle/input/100-bird-species/train/JACOBIN PIGEON
# There are 0 directories and 181 images in /kaggle/input/100-bird-species/train/CRESTED SERPENT EAGLE
# There are 0 directories and 144 images in /kaggle/input/100-bird-species/train/IMPERIAL SHAQ
# There are 0 directories and 132 images in /kaggle/input/100-bird-species/train/BARROWS GOLDENEYE
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/FRIGATE
# There are 0 directories and 137 images in /kaggle/input/100-bird-species/train/TRUMPTER SWAN
# There are 0 directories and 162 images in /kaggle/input/100-bird-species/train/INLAND DOTTEREL
# There are 0 directories and 153 images in /kaggle/input/100-bird-species/train/SAMATRAN THRUSH
# There are 0 directories and 142 images in /kaggle/input/100-bird-species/train/BLACK AND YELLOW BROADBILL
# There are 0 directories and 160 images in /kaggle/input/100-bird-species/train/BORNEAN LEAFBIRD
# There are 0 directories and 157 images in /kaggle/input/100-bird-species/train/LAZULI BUNTING
# There are 0 directories and 135 images in /kaggle/input/100-bird-species/train/EUROPEAN GOLDFINCH
# There are 0 directories and 139 images in /kaggle/input/100-bird-species/train/AMERICAN REDSTART
# There are 0 directories and 135 images in /kaggle/input/100-bird-species/train/CRANE HAWK
# There are 0 directories and 135 images in /kaggle/input/100-bird-species/train/NORTHERN RED BISHOP
# There are 0 directories and 162 images in /kaggle/input/100-bird-species/train/GOLDEN EAGLE

# %% [markdown]
# ##### How many classes do we have?

# %%
num_of_bird_groups = len(os.listdir("/kaggle/input/100-bird-species/train"))
num_of_bird_groups
# Out:
# 510

# %% [markdown]
# ##### What are the class names?

# %%
import pathlib 
import numpy as np

data_dir = pathlib.Path("/kaggle/input/100-bird-species/train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")])) # creating a list of class names from subdirectory 
print(class_names)
# Out:
# ['ABBOTTS BABBLER' 'ABBOTTS BOOBY' 'ABYSSINIAN GROUND HORNBILL'
#  'AFRICAN CROWNED CRANE' 'AFRICAN EMERALD CUCKOO' 'AFRICAN FIREFINCH'
#  'AFRICAN OYSTER CATCHER' 'AFRICAN PIED HORNBILL' 'AFRICAN PYGMY GOOSE'
#  'ALBATROSS' 'ALBERTS TOWHEE' 'ALEXANDRINE PARAKEET' 'ALPINE CHOUGH'
#  'ALTAMIRA YELLOWTHROAT' 'AMERICAN AVOCET' 'AMERICAN BITTERN'
#  'AMERICAN COOT' 'AMERICAN FLAMINGO' 'AMERICAN GOLDFINCH'
#  'AMERICAN KESTREL' 'AMERICAN PIPIT' 'AMERICAN REDSTART' 'AMERICAN ROBIN'
#  'AMERICAN WIGEON' 'AMETHYST WOODSTAR' 'ANDEAN GOOSE' 'ANDEAN LAPWING'
#  'ANDEAN SISKIN' 'ANHINGA' 'ANIANIAU' 'ANNAS HUMMINGBIRD' 'ANTBIRD'
#  'ANTILLEAN EUPHONIA' 'APAPANE' 'APOSTLEBIRD' 'ARARIPE MANAKIN'
#  'ASHY STORM PETREL' 'ASHY THRUSHBIRD' 'ASIAN CRESTED IBIS'
#  'ASIAN DOLLARD BIRD' 'ASIAN GREEN BEE EATER' 'AUCKLAND SHAQ'
#  'AUSTRAL CANASTERO' 'AUSTRALASIAN FIGBIRD' 'AVADAVAT' 'AZARAS SPINETAIL'
#  'AZURE BREASTED PITTA' 'AZURE JAY' 'AZURE TANAGER' 'AZURE TIT'
#  'BAIKAL TEAL' 'BALD EAGLE' 'BALD IBIS' 'BALI STARLING' 'BALTIMORE ORIOLE'
#  'BANANAQUIT' 'BAND TAILED GUAN' 'BANDED BROADBILL' 'BANDED PITA'
#  'BANDED STILT' 'BAR-TAILED GODWIT' 'BARN OWL' 'BARN SWALLOW'
#  'BARRED PUFFBIRD' 'BARROWS GOLDENEYE' 'BAY-BREASTED WARBLER'
#  'BEARDED BARBET' 'BEARDED BELLBIRD' 'BEARDED REEDLING'
#  'BELTED KINGFISHER' 'BIRD OF PARADISE' 'BLACK AND YELLOW BROADBILL'
#  'BLACK BAZA' 'BLACK COCKATO' 'BLACK FACED SPOONBILL' 'BLACK FRANCOLIN'
#  'BLACK HEADED CAIQUE' 'BLACK NECKED STILT' 'BLACK SKIMMER' 'BLACK SWAN'
#  'BLACK TAIL CRAKE' 'BLACK THROATED BUSHTIT' 'BLACK THROATED HUET'
#  'BLACK THROATED WARBLER' 'BLACK VENTED SHEARWATER' 'BLACK VULTURE'
#  'BLACK-CAPPED CHICKADEE' 'BLACK-NECKED GREBE' 'BLACK-THROATED SPARROW'
#  'BLACKBURNIAM WARBLER' 'BLONDE CRESTED WOODPECKER' 'BLOOD PHEASANT'
#  'BLUE COAU' 'BLUE DACNIS' 'BLUE GRAY GNATCATCHER' 'BLUE GROSBEAK'
#  'BLUE GROUSE' 'BLUE HERON' 'BLUE MALKOHA' 'BLUE THROATED TOUCANET'
#  'BOBOLINK' 'BORNEAN BRISTLEHEAD' 'BORNEAN LEAFBIRD' 'BORNEAN PHEASANT'
#  'BRANDT CORMARANT' 'BREWERS BLACKBIRD' 'BROWN CREPPER'
#  'BROWN HEADED COWBIRD' 'BROWN NOODY' 'BROWN THRASHER' 'BUFFLEHEAD'
#  'BULWERS PHEASANT' 'BURCHELLS COURSER' 'BUSH TURKEY' 'CAATINGA CACHOLOTE'
#  'CACTUS WREN' 'CALIFORNIA CONDOR' 'CALIFORNIA GULL' 'CALIFORNIA QUAIL'
#  'CAMPO FLICKER' 'CANARY' 'CANVASBACK' 'CAPE GLOSSY STARLING'
#  'CAPE LONGCLAW' 'CAPE MAY WARBLER' 'CAPE ROCK THRUSH' 'CAPPED HERON'
#  'CAPUCHINBIRD' 'CARMINE BEE-EATER' 'CASPIAN TERN' 'CASSOWARY'
#  'CEDAR WAXWING' 'CERULEAN WARBLER' 'CHARA DE COLLAR' 'CHATTERING LORY'
#  'CHESTNET BELLIED EUPHONIA' 'CHINESE BAMBOO PARTRIDGE'
#  'CHINESE POND HERON' 'CHIPPING SPARROW' 'CHUCAO TAPACULO'
#  'CHUKAR PARTRIDGE' 'CINNAMON ATTILA' 'CINNAMON FLYCATCHER'
#  'CINNAMON TEAL' 'CLARKS GREBE' 'CLARKS NUTCRACKER' 'COCK OF THE  ROCK'
#  'COCKATOO' 'COLLARED ARACARI' 'COLLARED CRESCENTCHEST' 'COMMON FIRECREST'
#  'COMMON GRACKLE' 'COMMON HOUSE MARTIN' 'COMMON IORA' 'COMMON LOON'
#  'COMMON POORWILL' 'COMMON STARLING' 'COPPERSMITH BARBET'
#  'COPPERY TAILED COUCAL' 'CRAB PLOVER' 'CRANE HAWK'
#  'CREAM COLORED WOODPECKER' 'CRESTED AUKLET' 'CRESTED CARACARA'
#  'CRESTED COUA' 'CRESTED FIREBACK' 'CRESTED KINGFISHER' 'CRESTED NUTHATCH'
#  'CRESTED OROPENDOLA' 'CRESTED SERPENT EAGLE' 'CRESTED SHRIKETIT'
#  'CRESTED WOOD PARTRIDGE' 'CRIMSON CHAT' 'CRIMSON SUNBIRD' 'CROW'
#  'CROWNED PIGEON' 'CUBAN TODY' 'CUBAN TROGON' 'CURL CRESTED ARACURI'
#  'D-ARNAUDS BARBET' 'DALMATIAN PELICAN' 'DARJEELING WOODPECKER'
#  'DARK EYED JUNCO' 'DAURIAN REDSTART' 'DEMOISELLE CRANE'
#  'DOUBLE BARRED FINCH' 'DOUBLE BRESTED CORMARANT' 'DOUBLE EYED FIG PARROT'
#  'DOWNY WOODPECKER' 'DUSKY LORY' 'DUSKY ROBIN' 'EARED PITA'
#  'EASTERN BLUEBIRD' 'EASTERN BLUEBONNET' 'EASTERN GOLDEN WEAVER'
#  'EASTERN MEADOWLARK' 'EASTERN ROSELLA' 'EASTERN TOWEE'
#  'EASTERN WIP POOR WILL' 'EASTERN YELLOW ROBIN' 'ECUADORIAN HILLSTAR'
#  'EGYPTIAN GOOSE' 'ELEGANT TROGON' 'ELLIOTS  PHEASANT' 'EMERALD TANAGER'
#  'EMPEROR PENGUIN' 'EMU' 'ENGGANO MYNA' 'EURASIAN BULLFINCH'
#  'EURASIAN GOLDEN ORIOLE' 'EURASIAN MAGPIE' 'EUROPEAN GOLDFINCH'
#  'EUROPEAN TURTLE DOVE' 'EVENING GROSBEAK' 'FAIRY BLUEBIRD'
#  'FAIRY PENGUIN' 'FAIRY TERN' 'FAN TAILED WIDOW' 'FASCIATED WREN'
#  'FIERY MINIVET' 'FIORDLAND PENGUIN' 'FIRE TAILLED MYZORNIS'
#  'FLAME BOWERBIRD' 'FLAME TANAGER' 'FOREST WAGTAIL' 'FRIGATE'
#  'FRILL BACK PIGEON' 'GAMBELS QUAIL' 'GANG GANG COCKATOO'
#  'GILA WOODPECKER' 'GILDED FLICKER' 'GLOSSY IBIS' 'GO AWAY BIRD'
#  'GOLD WING WARBLER' 'GOLDEN BOWER BIRD' 'GOLDEN CHEEKED WARBLER'
#  'GOLDEN CHLOROPHONIA' 'GOLDEN EAGLE' 'GOLDEN PARAKEET' 'GOLDEN PHEASANT'
#  'GOLDEN PIPIT' 'GOULDIAN FINCH' 'GRANDALA' 'GRAY CATBIRD' 'GRAY KINGBIRD'
#  'GRAY PARTRIDGE' 'GREAT ARGUS' 'GREAT GRAY OWL' 'GREAT JACAMAR'
#  'GREAT KISKADEE' 'GREAT POTOO' 'GREAT TINAMOU' 'GREAT XENOPS'
#  'GREATER PEWEE' 'GREATER PRAIRIE CHICKEN' 'GREATOR SAGE GROUSE'
#  'GREEN BROADBILL' 'GREEN JAY' 'GREEN MAGPIE' 'GREEN WINGED DOVE'
#  'GREY CUCKOOSHRIKE' 'GREY HEADED FISH EAGLE' 'GREY PLOVER'
#  'GROVED BILLED ANI' 'GUINEA TURACO' 'GUINEAFOWL' 'GURNEYS PITTA'
#  'GYRFALCON' 'HAMERKOP' 'HARLEQUIN DUCK' 'HARLEQUIN QUAIL' 'HARPY EAGLE'
#  'HAWAIIAN GOOSE' 'HAWFINCH' 'HELMET VANGA' 'HEPATIC TANAGER'
#  'HIMALAYAN BLUETAIL' 'HIMALAYAN MONAL' 'HOATZIN' 'HOODED MERGANSER'
#  'HOOPOES' 'HORNED GUAN' 'HORNED LARK' 'HORNED SUNGEM' 'HOUSE FINCH'
#  'HOUSE SPARROW' 'HYACINTH MACAW' 'IBERIAN MAGPIE' 'IBISBILL'
#  'IMPERIAL SHAQ' 'INCA TERN' 'INDIAN BUSTARD' 'INDIAN PITTA'
#  'INDIAN ROLLER' 'INDIAN VULTURE' 'INDIGO BUNTING' 'INDIGO FLYCATCHER'
#  'INLAND DOTTEREL' 'IVORY BILLED ARACARI' 'IVORY GULL' 'IWI' 'JABIRU'
#  'JACK SNIPE' 'JACOBIN PIGEON' 'JANDAYA PARAKEET' 'JAPANESE ROBIN'
#  'JAVA SPARROW' 'JOCOTOCO ANTPITTA' 'KAGU' 'KAKAPO' 'KILLDEAR'
#  'KING EIDER' 'KING VULTURE' 'KIWI' 'KOOKABURRA' 'LARK BUNTING'
#  'LAUGHING GULL' 'LAZULI BUNTING' 'LESSER ADJUTANT' 'LILAC ROLLER'
#  'LIMPKIN' 'LITTLE AUK' 'LOGGERHEAD SHRIKE' 'LONG-EARED OWL'
#  'LOONEY BIRDS' 'LUCIFER HUMMINGBIRD' 'MAGPIE GOOSE' 'MALABAR HORNBILL'
#  'MALACHITE KINGFISHER' 'MALAGASY WHITE EYE' 'MALEO' 'MALLARD DUCK'
#  'MANDRIN DUCK' 'MANGROVE CUCKOO' 'MARABOU STORK' 'MASKED BOBWHITE'
#  'MASKED BOOBY' 'MASKED LAPWING' 'MCKAYS BUNTING' 'MERLIN'
#  'MIKADO  PHEASANT' 'MILITARY MACAW' 'MOURNING DOVE' 'MYNA'
#  'NICOBAR PIGEON' 'NOISY FRIARBIRD' 'NORTHERN BEARDLESS TYRANNULET'
#  'NORTHERN CARDINAL' 'NORTHERN FLICKER' 'NORTHERN FULMAR'
#  'NORTHERN GANNET' 'NORTHERN GOSHAWK' 'NORTHERN JACANA'
#  'NORTHERN MOCKINGBIRD' 'NORTHERN PARULA' 'NORTHERN RED BISHOP'
#  'NORTHERN SHOVELER' 'OCELLATED TURKEY' 'OKINAWA RAIL'
#  'ORANGE BRESTED BUNTING' 'ORIENTAL BAY OWL' 'ORNATE HAWK EAGLE' 'OSPREY'
#  'OSTRICH' 'OVENBIRD' 'OYSTER CATCHER' 'PAINTED BUNTING' 'PALILA'
#  'PALM NUT VULTURE' 'PARADISE TANAGER' 'PARAKETT  AKULET' 'PARUS MAJOR'
#  'PATAGONIAN SIERRA FINCH' 'PEACOCK' 'PEREGRINE FALCON' 'PHAINOPEPLA'
#  'PHILIPPINE EAGLE' 'PINK ROBIN' 'PLUSH CRESTED JAY' 'POMARINE JAEGER'
#  'PUFFIN' 'PUNA TEAL' 'PURPLE FINCH' 'PURPLE GALLINULE' 'PURPLE MARTIN'
#  'PURPLE SWAMPHEN' 'PYGMY KINGFISHER' 'PYRRHULOXIA' 'QUETZAL'
#  'RAINBOW LORIKEET' 'RAZORBILL' 'RED BEARDED BEE EATER'
#  'RED BELLIED PITTA' 'RED BILLED TROPICBIRD' 'RED BROWED FINCH'
#  'RED FACED CORMORANT' 'RED FACED WARBLER' 'RED FODY' 'RED HEADED DUCK'
#  'RED HEADED WOODPECKER' 'RED KNOT' 'RED LEGGED HONEYCREEPER'
#  'RED NAPED TROGON' 'RED SHOULDERED HAWK' 'RED TAILED HAWK'
#  'RED TAILED THRUSH' 'RED WINGED BLACKBIRD' 'RED WISKERED BULBUL'
#  'REGENT BOWERBIRD' 'RING-NECKED PHEASANT' 'ROADRUNNER' 'ROCK DOVE'
#  'ROSE BREASTED COCKATOO' 'ROSE BREASTED GROSBEAK' 'ROSEATE SPOONBILL'
#  'ROSY FACED LOVEBIRD' 'ROUGH LEG BUZZARD' 'ROYAL FLYCATCHER'
#  'RUBY CROWNED KINGLET' 'RUBY THROATED HUMMINGBIRD' 'RUDDY SHELDUCK'
#  'RUDY KINGFISHER' 'RUFOUS KINGFISHER' 'RUFOUS TREPE' 'RUFUOS MOTMOT'
#  'SAMATRAN THRUSH' 'SAND MARTIN' 'SANDHILL CRANE' 'SATYR TRAGOPAN'
#  'SAYS PHOEBE' 'SCARLET CROWNED FRUIT DOVE' 'SCARLET FACED LIOCICHLA'
#  'SCARLET IBIS' 'SCARLET MACAW' 'SCARLET TANAGER' 'SHOEBILL'
#  'SHORT BILLED DOWITCHER' 'SMITHS LONGSPUR' 'SNOW GOOSE' 'SNOWY EGRET'
#  'SNOWY OWL' 'SNOWY PLOVER' 'SORA' 'SPANGLED COTINGA' 'SPLENDID WREN'
#  'SPOON BILED SANDPIPER' 'SPOTTED CATBIRD' 'SPOTTED WHISTLING DUCK'
#  'SQUACCO HERON' 'SRI LANKA BLUE MAGPIE' 'STEAMER DUCK'
#  'STORK BILLED KINGFISHER' 'STRIATED CARACARA' 'STRIPED OWL'
#  'STRIPPED MANAKIN' 'STRIPPED SWALLOW' 'SUNBITTERN' 'SUPERB STARLING'
#  'SURF SCOTER' 'SWINHOES PHEASANT' 'TAILORBIRD' 'TAIWAN MAGPIE' 'TAKAHE'
#  'TASMANIAN HEN' 'TAWNY FROGMOUTH' 'TEAL DUCK' 'TIT MOUSE' 'TOUCHAN'
#  'TOWNSENDS WARBLER' 'TREE SWALLOW' 'TRICOLORED BLACKBIRD'
#  'TROPICAL KINGBIRD' 'TRUMPTER SWAN' 'TURKEY VULTURE' 'TURQUOISE MOTMOT'
#  'UMBRELLA BIRD' 'VARIED THRUSH' 'VEERY' 'VENEZUELIAN TROUPIAL' 'VERDIN'
#  'VERMILION FLYCATHER' 'VICTORIA CROWNED PIGEON' 'VIOLET BACKED STARLING'
#  'VIOLET GREEN SWALLOW' 'VIOLET TURACO' 'VISAYAN HORNBILL'
#  'VULTURINE GUINEAFOWL' 'WALL CREAPER' 'WATTLED CURASSOW'
#  'WATTLED LAPWING' 'WHIMBREL' 'WHITE BREASTED WATERHEN'
#  'WHITE BROWED CRAKE' 'WHITE CHEEKED TURACO' 'WHITE CRESTED HORNBILL'
#  'WHITE EARED HUMMINGBIRD' 'WHITE NECKED RAVEN' 'WHITE TAILED TROPIC'
#  'WHITE THROATED BEE EATER' 'WILD TURKEY' 'WILLOW PTARMIGAN'
#  'WILSONS BIRD OF PARADISE' 'WOOD DUCK' 'WOOD THRUSH'
#  'WOODLAND KINGFISHER' 'WRENTIT' 'YELLOW BELLIED FLOWERPECKER'
#  'YELLOW CACIQUE' 'YELLOW HEADED BLACKBIRD' 'ZEBRA DOVE']

# %% [markdown]
# ##### A function to visualize images randomly

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # setting up the image directory
  target_folder = target_dir + target_class

  #get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  #read image and plotting it
  img = mpimg.imread(target_folder + "/" + random_image[0] )
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off")

  print(f"Image shape: {img.shape}")
  
  return img

# %%
img = view_random_image(target_dir = "/kaggle/input/100-bird-species/train/",
                        target_class = "VICTORIA CROWNED PIGEON") # or we can write nike instead of converse to see converse examples
# Out:
# Image shape: (224, 224, 3)

# %%
import tensorflow as tf
img.shape #(width, height, colour channels)
# Out:
# (224, 224, 3)

# %% [markdown]
# ##### More visualization :D

# %%
plt.figure(figsize = (15,7))
plt.subplot(1,3,1)
steak_image = view_random_image("/kaggle/input/100-bird-species/train/", "UMBRELLA BIRD")
plt.subplot(1,3,2)
pizza_image = view_random_image("/kaggle/input/100-bird-species/train/", "YELLOW HEADED BLACKBIRD")
plt.subplot(1,3,3)
pizza_image = view_random_image("/kaggle/input/100-bird-species/train/", "INDIAN PITTA")
# Out:
# Image shape: (224, 224, 3)
# Image shape: (224, 224, 3)
# Image shape: (224, 224, 3)

# %% [markdown]
# ## 2. Data Preprocessing

# %%
import matplotlib.pyplot as plt
import pathlib, os, random
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential

# %%
train_dir = "/kaggle/input/100-bird-species/train/"
test_dir = "/kaggle/input/100-bird-species/test/"
val_dir = "/kaggle/input/100-bird-species/valid/"

# %%
# Rescale
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)
valid_datagen = ImageDataGenerator(rescale = 1./255)

# data transfer from directories to batches
train_data = train_datagen.flow_from_directory(directory = train_dir,
                                               batch_size= 32,
                                               target_size= (224,224),
                                               class_mode = "categorical")

test_data = test_datagen.flow_from_directory(directory = test_dir,
                                               batch_size = 32,
                                               target_size = (224,224),
                                               class_mode = "categorical")

val_data = valid_datagen.flow_from_directory(directory = val_dir,
                                               batch_size = 32,
                                               target_size = (224,224),
                                               class_mode = "categorical")
# Out:
# Found 81950 images belonging to 510 classes.
# Found 2550 images belonging to 510 classes.
# Found 2550 images belonging to 510 classes.

# %% [markdown]
# ## 3.Creating and fitting the Model

# %%
# 1. Create a base model with tf.keras.applications

base_model = tf.keras.applications.InceptionV3(include_top= False,)

# 2. Freeze the base model
base_model.trainable = False

#3. Create inputs into models
inputs = tf.keras.layers.Input(shape =(300,300,3), name = "input-layer")

#4. Rescaling
#x = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)(inputs)

#5. Pass the inputs 
x = base_model(inputs)
print(f"Shape after passing inputs through base model: {x.shape}")

# 6. Average pool the outputs of the base model
x = tf.keras.layers.GlobalAveragePooling2D(name = "global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

#7. Create the output activation layer
outputs = tf.keras.layers.Dense(510, activation = "softmax", name = "output-layer")(x)

# 8. Combine the inputs with outputs into a model
model_0 = tf.keras.Model(inputs, outputs)

# 9. Compile the model
model_0.compile(loss = "categorical_crossentropy",
                optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
                metrics = ["accuracy"])


history = model_0.fit(train_data,
                                 epochs=10,
                                 steps_per_epoch = len(train_data),
                                 validation_data = val_data,
                                 validation_steps = int(0.25*len(val_data)),)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 4s 0us/step
# 87924736/87910968 [==============================] - 4s 0us/step
# Shape after passing inputs through base model: (None, 8, 8, 2048)
# Shape after GlobalAveragePooling2D: (None, 2048)
# Epoch 1/10
# 2561/2561 [==============================] - 705s 271ms/step - loss: 10.3796 - accuracy: 0.4819 - val_loss: 7.0023 - val_accuracy: 0.6266
# Epoch 2/10
# 2561/2561 [==============================] - 247s 97ms/step - loss: 7.5282 - accuracy: 0.6713 - val_loss: 5.6057 - val_accuracy: 0.7625
# Epoch 3/10
# 2561/2561 [==============================] - 240s 94ms/step - loss: 6.2488 - accuracy: 0.7386 - val_loss: 7.0602 - val_accuracy: 0.7563
# Epoch 4/10
# 2561/2561 [==============================] - 240s 94ms/step - loss: 5.5127 - accuracy: 0.7749 - val_loss: 5.6347 - val_accuracy: 0.8000
# Epoch 5/10
# 2561/2561 [==============================] - 234s 91ms/step - loss: 4.8679 - accuracy: 0.8030 - val_loss: 5.8897 - val_accuracy: 0.7937
# Epoch 6/10
# 2561/2561 [==============================] - 247s 96ms/step - loss: 4.3484 - accuracy: 0.8243 - val_loss: 5.9549 - val_accuracy: 0.8094
# Epoch 7/10
# 2561/2561 [==============================] - 241s 94ms/step - loss: 3.8769 - accuracy: 0.8434 - val_loss: 5.3669 - val_accuracy: 0.8328
# Epoch 8/10
# 2561/2561 [==============================] - 241s 94ms/step - loss: 3.5391 - accuracy: 0.8567 - val_loss: 7.7365 - val_accuracy: 0.8016
# Epoch 9/10
# 2561/2561 [==============================] - 253s 99ms/step - loss: 3.2887 - accuracy: 0.8688 - val_loss: 6.5363 - val_accuracy: 0.8188
# Epoch 10/10
# 2561/2561 [==============================] - 257s 100ms/step - loss: 2.9772 - accuracy: 0.8803 - val_loss: 7.2293 - val_accuracy: 0.8031

# %%
model_0.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input-layer (InputLayer)     [(None, 300, 300, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling_layer (None, 2048)              0
# _________________________________________________________________
# output-layer (Dense)         (None, 510)               1044990
# =================================================================
# Total params: 22,847,774
# Trainable params: 1,044,990
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_0.evaluate(test_data)
# Out:
# 80/80 [==============================] - 25s 316ms/step - loss: 5.3500 - accuracy: 0.8325
# [5.349952697753906, 0.8325490355491638]

# %%
def plot_loss_curves(history):

  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["accuracy"]
  val_accuracy = history.history["val_accuracy"]

  epochs = range(len(history.history["loss"]))

  #plot loss
  plt.plot(epochs, loss, label = "training_loss")
  plt.plot(epochs, val_loss, label = "val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()

  #plot accuracy
  plt.figure() 
  plt.plot(epochs, accuracy, label = "training_accuracy")
  plt.plot(epochs, val_accuracy, label = "val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_loss_curves(history)

# %% [markdown]
# ## 4. Freeze top layers of Base Model

# %%
# To begin fine-tuning lets start by setting the last 10 layers as trainable

base_model.trainable = True

# Un-freeze last 10 layers
for layer in base_model.layers[:-10]:
  layer.trainable = False

# Recompile (we have to compile model every time there is a change)
model_0.compile(loss = "categorical_crossentropy",
                optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), # when fine-tuning you typically want to lower lr by 10x
                 metrics = ["accuracy"] )

# %%
# Check which layers are trainable
for layer_number, layer in enumerate(model_0.layers[1].layers):
  print(layer_number, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 conv2d False
# 2 batch_normalization False
# 3 activation False
# 4 conv2d_1 False
# 5 batch_normalization_1 False
# 6 activation_1 False
# 7 conv2d_2 False
# 8 batch_normalization_2 False
# 9 activation_2 False
# 10 max_pooling2d False
# 11 conv2d_3 False
# 12 batch_normalization_3 False
# 13 activation_3 False
# 14 conv2d_4 False
# 15 batch_normalization_4 False
# 16 activation_4 False
# 17 max_pooling2d_1 False
# 18 conv2d_8 False
# 19 batch_normalization_8 False
# 20 activation_8 False
# 21 conv2d_6 False
# 22 conv2d_9 False
# 23 batch_normalization_6 False
# 24 batch_normalization_9 False
# 25 activation_6 False
# 26 activation_9 False
# 27 average_pooling2d False
# 28 conv2d_5 False
# 29 conv2d_7 False
# 30 conv2d_10 False
# 31 conv2d_11 False
# 32 batch_normalization_5 False
# 33 batch_normalization_7 False
# 34 batch_normalization_10 False
# 35 batch_normalization_11 False
# 36 activation_5 False
# 37 activation_7 False
# 38 activation_10 False
# 39 activation_11 False
# 40 mixed0 False
# 41 conv2d_15 False
# 42 batch_normalization_15 False
# 43 activation_15 False
# 44 conv2d_13 False
# 45 conv2d_16 False
# 46 batch_normalization_13 False
# 47 batch_normalization_16 False
# 48 activation_13 False
# 49 activation_16 False
# 50 average_pooling2d_1 False
# 51 conv2d_12 False
# 52 conv2d_14 False
# 53 conv2d_17 False
# 54 conv2d_18 False
# 55 batch_normalization_12 False
# 56 batch_normalization_14 False
# 57 batch_normalization_17 False
# 58 batch_normalization_18 False
# 59 activation_12 False
# 60 activation_14 False
# 61 activation_17 False
# 62 activation_18 False
# 63 mixed1 False
# 64 conv2d_22 False
# 65 batch_normalization_22 False
# 66 activation_22 False
# 67 conv2d_20 False
# 68 conv2d_23 False
# 69 batch_normalization_20 False
# 70 batch_normalization_23 False
# 71 activation_20 False
# 72 activation_23 False
# 73 average_pooling2d_2 False
# 74 conv2d_19 False
# 75 conv2d_21 False
# 76 conv2d_24 False
# 77 conv2d_25 False
# 78 batch_normalization_19 False
# 79 batch_normalization_21 False
# 80 batch_normalization_24 False
# 81 batch_normalization_25 False
# 82 activation_19 False
# 83 activation_21 False
# 84 activation_24 False
# 85 activation_25 False
# 86 mixed2 False
# 87 conv2d_27 False
# 88 batch_normalization_27 False
# 89 activation_27 False
# 90 conv2d_28 False
# 91 batch_normalization_28 False
# 92 activation_28 False
# 93 conv2d_26 False
# 94 conv2d_29 False
# 95 batch_normalization_26 False
# 96 batch_normalization_29 False
# 97 activation_26 False
# 98 activation_29 False
# 99 max_pooling2d_2 False
# 100 mixed3 False
# 101 conv2d_34 False
# 102 batch_normalization_34 False
# 103 activation_34 False
# 104 conv2d_35 False
# 105 batch_normalization_35 False
# 106 activation_35 False
# 107 conv2d_31 False
# 108 conv2d_36 False
# 109 batch_normalization_31 False
# 110 batch_normalization_36 False
# 111 activation_31 False
# 112 activation_36 False
# 113 conv2d_32 False
# 114 conv2d_37 False
# 115 batch_normalization_32 False
# 116 batch_normalization_37 False
# 117 activation_32 False
# 118 activation_37 False
# 119 average_pooling2d_3 False
# 120 conv2d_30 False
# 121 conv2d_33 False
# 122 conv2d_38 False
# 123 conv2d_39 False
# 124 batch_normalization_30 False
# 125 batch_normalization_33 False
# 126 batch_normalization_38 False
# 127 batch_normalization_39 False
# 128 activation_30 False
# 129 activation_33 False
# 130 activation_38 False
# 131 activation_39 False
# 132 mixed4 False
# 133 conv2d_44 False
# 134 batch_normalization_44 False
# 135 activation_44 False
# 136 conv2d_45 False
# 137 batch_normalization_45 False
# 138 activation_45 False
# 139 conv2d_41 False
# 140 conv2d_46 False
# 141 batch_normalization_41 False
# 142 batch_normalization_46 False
# 143 activation_41 False
# 144 activation_46 False
# 145 conv2d_42 False
# 146 conv2d_47 False
# 147 batch_normalization_42 False
# 148 batch_normalization_47 False
# 149 activation_42 False
# 150 activation_47 False
# 151 average_pooling2d_4 False
# 152 conv2d_40 False
# 153 conv2d_43 False
# 154 conv2d_48 False
# 155 conv2d_49 False
# 156 batch_normalization_40 False
# 157 batch_normalization_43 False
# 158 batch_normalization_48 False
# 159 batch_normalization_49 False
# 160 activation_40 False
# 161 activation_43 False
# 162 activation_48 False
# 163 activation_49 False
# 164 mixed5 False
# 165 conv2d_54 False
# 166 batch_normalization_54 False
# 167 activation_54 False
# 168 conv2d_55 False
# 169 batch_normalization_55 False
# 170 activation_55 False
# 171 conv2d_51 False
# 172 conv2d_56 False
# 173 batch_normalization_51 False
# 174 batch_normalization_56 False
# 175 activation_51 False
# 176 activation_56 False
# 177 conv2d_52 False
# 178 conv2d_57 False
# 179 batch_normalization_52 False
# 180 batch_normalization_57 False
# 181 activation_52 False
# 182 activation_57 False
# 183 average_pooling2d_5 False
# 184 conv2d_50 False
# 185 conv2d_53 False
# 186 conv2d_58 False
# 187 conv2d_59 False
# 188 batch_normalization_50 False
# 189 batch_normalization_53 False
# 190 batch_normalization_58 False
# 191 batch_normalization_59 False
# 192 activation_50 False
# 193 activation_53 False
# 194 activation_58 False
# 195 activation_59 False
# 196 mixed6 False
# 197 conv2d_64 False
# 198 batch_normalization_64 False
# 199 activation_64 False
# 200 conv2d_65 False
# 201 batch_normalization_65 False
# 202 activation_65 False
# 203 conv2d_61 False
# 204 conv2d_66 False
# 205 batch_normalization_61 False
# 206 batch_normalization_66 False
# 207 activation_61 False
# 208 activation_66 False
# 209 conv2d_62 False
# 210 conv2d_67 False
# 211 batch_normalization_62 False
# 212 batch_normalization_67 False
# 213 activation_62 False
# 214 activation_67 False
# 215 average_pooling2d_6 False
# 216 conv2d_60 False
# 217 conv2d_63 False
# 218 conv2d_68 False
# 219 conv2d_69 False
# 220 batch_normalization_60 False
# 221 batch_normalization_63 False
# 222 batch_normalization_68 False
# 223 batch_normalization_69 False
# 224 activation_60 False
# 225 activation_63 False
# 226 activation_68 False
# 227 activation_69 False
# 228 mixed7 False
# 229 conv2d_72 False
# 230 batch_normalization_72 False
# 231 activation_72 False
# 232 conv2d_73 False
# 233 batch_normalization_73 False
# 234 activation_73 False
# 235 conv2d_70 False
# 236 conv2d_74 False
# 237 batch_normalization_70 False
# 238 batch_normalization_74 False
# 239 activation_70 False
# 240 activation_74 False
# 241 conv2d_71 False
# 242 conv2d_75 False
# 243 batch_normalization_71 False
# 244 batch_normalization_75 False
# 245 activation_71 False
# 246 activation_75 False
# 247 max_pooling2d_3 False
# 248 mixed8 False
# 249 conv2d_80 False
# 250 batch_normalization_80 False
# 251 activation_80 False
# 252 conv2d_77 False
# 253 conv2d_81 False
# 254 batch_normalization_77 False
# 255 batch_normalization_81 False
# 256 activation_77 False
# 257 activation_81 False
# 258 conv2d_78 False
# 259 conv2d_79 False
# 260 conv2d_82 False
# 261 conv2d_83 False
# 262 average_pooling2d_7 False
# 263 conv2d_76 False
# 264 batch_normalization_78 False
# 265 batch_normalization_79 False
# 266 batch_normalization_82 False
# 267 batch_normalization_83 False
# 268 conv2d_84 False
# 269 batch_normalization_76 False
# 270 activation_78 False
# 271 activation_79 False
# 272 activation_82 False
# 273 activation_83 False
# 274 batch_normalization_84 False
# 275 activation_76 False
# 276 mixed9_0 False
# 277 concatenate False
# 278 activation_84 False
# 279 mixed9 False
# 280 conv2d_89 False
# 281 batch_normalization_89 False
# 282 activation_89 False
# 283 conv2d_86 False
# 284 conv2d_90 False
# 285 batch_normalization_86 False
# 286 batch_normalization_90 False
# 287 activation_86 False
# 288 activation_90 False
# 289 conv2d_87 False
# 290 conv2d_88 False
# 291 conv2d_91 False
# 292 conv2d_92 False
# 293 average_pooling2d_8 False
# 294 conv2d_85 False
# 295 batch_normalization_87 False
# 296 batch_normalization_88 False
# 297 batch_normalization_91 False
# 298 batch_normalization_92 False
# 299 conv2d_93 False
# 300 batch_normalization_85 False
# 301 activation_87 True
# 302 activation_88 True
# 303 activation_91 True
# 304 activation_92 True
# 305 batch_normalization_93 True
# 306 activation_85 True
# 307 mixed9_1 True
# 308 concatenate_1 True
# 309 activation_93 True
# 310 mixed10 True

# %%
# Now we have unfrozen some of the layers on the top 
print(len(model_0.trainable_variables))
# Out:
# 3

# %% [markdown]
# ## 5. Fine-Tuning and Refitting

# %%
initial_epochs = 10
fine_tune_epochs = initial_epochs + 1

# Refit the model
history_2 = model_0.fit(train_data,
                       epochs = fine_tune_epochs,
                       validation_data = val_data,
                       validation_steps = int(0.25*len(val_data)),
                       initial_epoch =  history.epoch[-1],) # Start the epoch where it left before
# Out:
# Epoch 10/11
# 2561/2561 [==============================] - 248s 95ms/step - loss: 0.4972 - accuracy: 0.9670 - val_loss: 3.9489 - val_accuracy: 0.8750
# Epoch 11/11
# 2561/2561 [==============================] - 239s 93ms/step - loss: 0.2587 - accuracy: 0.9787 - val_loss: 3.2947 - val_accuracy: 0.8844

# %%
model_0.evaluate(test_data)
# Out:
# 80/80 [==============================] - 7s 92ms/step - loss: 2.6119 - accuracy: 0.9063
# [2.6119394302368164, 0.9062744975090027]

# %%
plot_loss_curves(history_2)

# %%
import lime
from lime import lime_image
from lime import submodular_pick

from skimage.segmentation import mark_boundaries

# %%
explainer = lime_image.LimeImageExplainer()

# %%
img = view_random_image(target_dir = "/kaggle/input/100-bird-species/test/",
                        target_class = "ABBOTTS BABBLER")

img = view_random_image(target_dir = "/kaggle/input/100-bird-species/train/",
                        target_class = "VICTORIA CROWNED PIGEON") # or we can write nike instead of converse to see converse examples
# Out:
# Image shape: (224, 224, 3)
# Image shape: (224, 224, 3)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image


img = view_random_image(target_dir = "/kaggle/input/100-bird-species/test/",
                        target_class = "VICTORIA CROWNED PIGEON") # or we can write nike instead of converse to see converse examples
# Out:
# Image shape: (224, 224, 3)

# %%
IMG_SIZE = (300, 300)
def transform_image(image_path, size):
    '''
    Function to transform an image to normalized numpy array
    '''
    img = image.load_img(image_path, target_size=size)
    img = image.img_to_array(img)# Transforming the image to get the shape as [channel, height, width]
    img = np.expand_dims(img, axis=0) # Adding dimension to convert array into a batch of size (1,299,299,3)
    img = img/255.0 # normalizing the image to keep within the range of 0.0 to 1.0
    
    return img

normalized_img = transform_image("/kaggle/input/100-bird-species/test/VICTORIA CROWNED PIGEON/1.jpg", IMG_SIZE)

# %%
exp = explainer.explain_instance(normalized_img[0], 
                                 model_0.predict, 
                                 top_labels=5, 
                                 hide_color=0, 
                                 num_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
plt.imshow(exp.segments)
plt.axis('off')
plt.show()

# %%
def generate_prediction_sample(exp, exp_class, weight = 0.1, show_positive = True, hide_background = True):
    '''
    Method to display and highlight super-pixels used by the black-box model to make predictions
    '''
    image, mask = exp.get_image_and_mask(exp_class, 
                                         positive_only=show_positive, 
                                         num_features=6, 
                                         hide_rest=hide_background,
                                         min_weight=weight
                                        )
    plt.imshow(mark_boundaries(image, mask))
    plt.axis('off')
    plt.show()
generate_prediction_sample(exp, exp.top_labels[0], show_positive = True, hide_background = True)

# %%
generate_prediction_sample(exp, exp.top_labels[0], show_positive = True, hide_background = False)

# %%
generate_prediction_sample(exp, exp.top_labels[0], show_positive = False, hide_background = False)

# %% [markdown]
# **If you find the work beneficial, upvote it! I expect your feedbacks on the project. Thanks, Emre**
